# %%
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 1. CSV

# %%
df = pd.read_csv('elbasan2021.csv')

# %%
df.to_csv('elbasan2021_copy.csv', index=False)

# %% [markdown]
# # 2. Excel

# %%
df = pd.read_excel('Excel_Sample.xlsx', sheet_name='Sheet1')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_excel('Excel_Sample.xlsx', index=False, sheet_name='Result')

# %% [markdown]
# # 3. Từ trang web

# %%
all_table = pd.read_html('https://vi.wikipedia.org/wiki/Kinh_t%E1%BA%BF_Vi%E1%BB%87t_Nam')
for i in range(0, int(len(all_table))):
    all_table[i]
# Out:
#                                      Kinh tế Việt Nam  \
# 0   Thành phố Hồ Chí Minh – trung tâm kinh tế lớn ...
# 1                                             Tiền tệ
# 2                                       Năm tài chính
# 3                                     Tổ chức kinh tế
# 4                                    Số liệu thống kê
# 5                                              Dân số
# 6                                                 GDP
# 7                                        Xếp hạng GDP
# 8                                     Tăng trưởng GDP
# 9                                       GDP đầu người
# 10                                  GDP theo lĩnh vực
# 11                                     Lạm phát (CPI)
# 12                                        Tỷ lệ nghèo
# 13                                         Hệ số Gini
# 14                                 Lực lượng lao động
# 15                          Cơ cấu lao động theo nghề
# ...

# %% [markdown]
# # 4. SQL (Đọc thêm bên file gốc)
